# %% [markdown]
# <a href="https://colab.research.google.com/github/prachi137/python/blob/pyhon/decoratorpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **prob1:Timing function execution**
#
# **prob2:Debugging function calls**
#
# **prob3:Cache return values**

# %%
#write a decorator thats mesures times and function takes execute
import time
def timer(func):
  def wrapper(*args, **kwargs):
    start = time.time()
    result = func(*args, **kwargs)
    end = time.time()
    print(f"{func.__name__} ran in {end - start} seconds")
    return result
  return wrapper

@timer
def example_function(n):
  time.sleep(n)
print(example_function(2))
# Out:
# example_function ran in 2.00016450881958 seconds
# None

# %%
#create a decorator to print the function and the values of its argument every time is function is called
def debug(func):
  def wrapper(*args,**kwargs):
    args_value =', '.join(str(arg) for arg in args)
    kwargs_value = ", ".join(f"{k}={v}" for k,v in kwargs.items())
    print(f"calling:{func.__name__} with args{args_value} and kwargs{kwargs_value}")
    return func(*args,**kwargs)
  return wrapper
@debug
def hello():
  print('hello')
@debug
def add(a,b):
  return a+b
hello()
add(1,2)
# Out:
# calling:hello with args and kwargs
# hello
# calling:add with args1, 2 and kwargs
# 3

# %%
#implement a decorator that cache the return values of a function so what when its called with the same arguments the cache value is returned instead of re-executioin the function
import time
def cache(func):
  cache_value = {} # Initialize cache_value outside the wrapper
  def wrapper(*args):
    if args in cache_value:
      print("Returning cached value")
      return cache_value[args]
    result = func(*args)
    cache_value[args] = result
    return result
  return wrapper

@cache
def long_runing_function(n):
  print("Executing long_runing_function")
  time.sleep(4)
  return n # Return n instead of a*b

print(long_runing_function(1))
print(long_runing_function(1))
print(long_runing_function(2))
print(long_runing_function(2))
print(long_runing_function(1))
# Out:
# Executing long_runing_function
# 1
# Returning cached value
# 1
# Executing long_runing_function
# 2
# Returning cached value
# 2
# Returning cached value
# 1
